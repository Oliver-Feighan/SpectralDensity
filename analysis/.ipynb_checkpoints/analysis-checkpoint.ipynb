# %% [markdown]
# # LHII Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

import mdtraj
import itertools

import matplotlib
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

import analysis


matplotlib.rc('font', **font)
# Out:
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.

# %%
def first_half(arr):
    return arr[1:len(arr)//2]

length = 10*1e3 #femtoseconds
dt = 2 #femtoseconds

run = f"{int(length/1e3)}ps_{dt}fs"

Mg_d = np.load(f"{run}_LHII_distances.npy")

avg_d = np.mean(Mg_d, axis=0)

closest_neighbours = np.where(avg_d < 1.5)[0]

fig, ax = plt.subplots(3,1)

for n, color in zip([5], ['red', 'blue', 'green']):
    for i in closest_neighbours:
        x = Mg_d[:,i] - np.mean(Mg_d[:,i])

        autocorr = first_half(analysis.autocorr(x))
        
        autocorr = np.concatenate((autocorr, autocorr[::-1]))

        repeated = np.tile(autocorr, n)

        spectrum = scipy.fft.fft(repeated)

        spectrum_normal_domain = np.fft.fftfreq(len(autocorr) * n, dt) 

        hilbert = scipy.signal.hilbert(np.real(spectrum))
        
        ax[0].plot(x, alpha=0.5, color='black')
        ax[1].plot(repeated, alpha=0.5, color='black')
        ax[2].plot(first_half(spectrum_normal_domain), abs(first_half(spectrum)), alpha=0.5, color='black')
        #ax[2].plot(first_half(spectrum_normal_domain), abs(first_half(np.abs(hilbert))), alpha=0.5, color='red')

ax[2].set_xscale('log')
ax[2].set_yscale('log')
    
fig.set_size_inches(12,12)

# %%
spectra_1000ps, domain_1000ps = np.load('1000ps_100fs_LHII_spectra.npy'), np.load('1000ps_100fs_LHII_domain.npy')
spectra_100ps, domain_100ps = np.load('100ps_10fs_LHII_spectra.npy'), np.load('100ps_10fs_LHII_domain.npy')
spectra_10ps, domain_10ps = np.load('10ps_2fs_LHII_spectra.npy'), np.load('10ps_2fs_LHII_domain.npy')

fig, ax = plt.subplots(4,1, sharex=True, sharey=True)

ax[0].set_xlim(1e-7, 1)
#ax[0].set_ylim(1e-10, 0.1)
ax[0].set_xscale('log')
ax[0].set_yscale('log')

for i in range(spectra_10ps.shape[0]):
    ax[0].plot(first_half(domain_10ps), first_half(abs(spectra_10ps[i])), alpha=0.1, color='black')

for i in range(spectra_100ps.shape[0]):
    ax[1].plot(first_half(domain_100ps), first_half(abs(spectra_100ps[i])), alpha=0.1, color='black')

for i in range(spectra_1000ps.shape[0]):
    ax[2].plot(first_half(domain_1000ps), first_half(abs(spectra_1000ps[i])), alpha=0.1, color='black')


avg_spectra_10ps = first_half(np.mean(abs(spectra_10ps), axis=0))
avg_spectra_100ps = first_half(np.mean(abs(spectra_100ps), axis=0))
avg_spectra_1000ps = first_half(np.mean(abs(spectra_1000ps), axis=0))

ax[0].plot(first_half(domain_10ps), np.abs(avg_spectra_10ps), color='blue')
ax[1].plot(first_half(domain_100ps), np.abs(avg_spectra_100ps), color='red')
ax[2].plot(first_half(domain_1000ps), np.abs(avg_spectra_1000ps), color='green')

ax[3].plot(first_half(domain_10ps), avg_spectra_10ps, color='black')
ax[3].plot(first_half(domain_100ps), avg_spectra_100ps, color='black')
ax[3].plot(first_half(domain_1000ps), avg_spectra_1000ps, color='black')

fig.set_size_inches(24, 12)

print(len(first_half(domain_10ps)))
print(len(first_half(domain_100ps)))
print(len(first_half(domain_1000ps)))
# Out:
# 24996
# 49996
# 49996

# %%
def resolution(length, timestep, cutoff=0):
    autocorr_length = 2 * (length - cutoff) - 2
        
    resolution = 1 / (timestep * autocorr_length)
    
    return resolution


def highest_frequency(timestep):
    return 1/(2*timestep)


fig, ax = plt.subplots()

MD_ns_lengths = [0.1, 1, 10, 100] # ns

timesteps = [1, 20, 50, 100, 200, 500, 1000] # fsbf

max_freqs = [highest_frequency(x) for x in timesteps]

res_mat = np.zeros((len(MD_ns_lengths), len(timesteps)))

for i, ns in enumerate(MD_ns_lengths):
    for j, dt in enumerate(timesteps):

        n_steps = 1e6 * ns / dt

        res, max_freq = resolution(n_steps, dt), highest_frequency(dt)
        
        print(f" MD length : {ns:2.2f} ns, timesteps : {dt : 3.0f} fs, highest period : {1e-3/res:3.0f} ps, lowest period : {1/max_freq} fs")
# Out:
#  MD length : 0.10 ns, timesteps :   1 fs, highest period : 200 ps, lowest period : 2.0 fs
#  MD length : 0.10 ns, timesteps :  20 fs, highest period : 200 ps, lowest period : 40.0 fs
#  MD length : 0.10 ns, timesteps :  50 fs, highest period : 200 ps, lowest period : 100.0 fs
#  MD length : 0.10 ns, timesteps :  100 fs, highest period : 200 ps, lowest period : 200.0 fs
#  MD length : 0.10 ns, timesteps :  200 fs, highest period : 200 ps, lowest period : 400.0 fs
#  MD length : 0.10 ns, timesteps :  500 fs, highest period : 199 ps, lowest period : 1000.0 fs
#  MD length : 0.10 ns, timesteps :  1000 fs, highest period : 198 ps, lowest period : 2000.0 fs
#  MD length : 1.00 ns, timesteps :   1 fs, highest period : 2000 ps, lowest period : 2.0 fs
#  MD length : 1.00 ns, timesteps :  20 fs, highest period : 2000 ps, lowest period : 40.0 fs
#  MD length : 1.00 ns, timesteps :  50 fs, highest period : 2000 ps, lowest period : 100.0 fs
#  MD length : 1.00 ns, timesteps :  100 fs, highest period : 2000 ps, lowest period : 200.0 fs
#  MD length : 1.00 ns, timesteps :  200 fs, highest period : 2000 ps, lowest period : 400.0 fs
#  MD length : 1.00 ns, timesteps :  500 fs, highest period : 1999 ps, lowest period : 1000.0 fs
#  MD length : 1.00 ns, timesteps :  1000 fs, highest period : 1998 ps, lowest period : 2000.0 fs
#  MD length : 10.00 ns, timesteps :   1 fs, highest period : 20000 ps, lowest period : 2.0 fs
#  MD length : 10.00 ns, timesteps :  20 fs, highest period : 20000 ps, lowest period : 40.0 fs
#  MD length : 10.00 ns, timesteps :  50 fs, highest period : 20000 ps, lowest period : 100.0 fs
#  MD length : 10.00 ns, timesteps :  100 fs, highest period : 20000 ps, lowest period : 200.0 fs
#  MD length : 10.00 ns, timesteps :  200 fs, highest period : 20000 ps, lowest period : 400.0 fs
#  MD length : 10.00 ns, timesteps :  500 fs, highest period : 19999 ps, lowest period : 1000.0 fs
#  MD length : 10.00 ns, timesteps :  1000 fs, highest period : 19998 ps, lowest period : 2000.0 fs
#  MD length : 100.00 ns, timesteps :   1 fs, highest period : 200000 ps, lowest period : 2.0 fs
#  MD length : 100.00 ns, timesteps :  20 fs, highest period : 200000 ps, lowest period : 40.0 fs
#  MD length : 100.00 ns, timesteps :  50 fs, highest period : 200000 ps, lowest period : 100.0 fs
#  MD length : 100.00 ns, timesteps :  100 fs, highest period : 200000 ps, lowest period : 200.0 fs
#  MD length : 100.00 ns, timesteps :  200 fs, highest period : 200000 ps, lowest period : 400.0 fs
#  MD length : 100.00 ns, timesteps :  500 fs, highest period : 199999 ps, lowest period : 1000.0 fs
#  MD length : 100.00 ns, timesteps :  1000 fs, highest period : 199998 ps, lowest period : 2000.0 fs

# %%
full_rmsd = mdtraj.rmsd(traj, traj, 0)
BCL_rmsd = mdtraj.rmsd(traj, traj, 0, atom_indices = BCL_atom_indices)

# %%
log = pd.read_csv("LH2_files/output/log.txt", sep="\t")
log["RMSD"] = full_rmsd
log["BCL RMSD"] = BCL_rmsd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-20a29fbbdab1> in <module>
#       1 log = pd.read_csv("LH2_files/output/log.txt", sep="\t")
# ----> 2 log["RMSD"] = full_rmsd
#       3 log["BCL RMSD"] = BCL_rmsd
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
#    4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/common.py in require_length_match(data, index)
#     530     if len(data) != len(index):
#     531         raise ValueError(
# --> 532             "Length of values "
#     533             f"({len(data)}) "
#     534             "does not match length of index "
#
# ValueError: Length of values (2624) does not match length of index (4000)

# %%
log
# Out:
#      #"Progress (%)"   Step  Potential Energy (kJ/mole)  Temperature (K)  \
# 0               0.0%     10               -2.868276e+06       300.578177
# 1               0.1%     20               -2.867977e+06       300.712337
# 2               0.1%     30               -2.868144e+06       300.805135
# 3               0.1%     40               -2.868425e+06       300.676495
# 4               0.1%     50               -2.868008e+06       300.446538
# ...              ...    ...                         ...              ...
# 3995           99.9%  39960               -2.869814e+06       300.520701
# 3996           99.9%  39970               -2.870865e+06       300.675209
# 3997          100.0%  39980               -2.868822e+06       299.869208
# 3998          100.0%  39990               -2.868310e+06       299.991418
# 3999          100.0%  40000               -2.869835e+06       300.595353
#
#       Speed (ns/day)
# 0              0.000
# 1              0.483
# 2              0.431
# 3              0.444
# 4              0.443
# ...              ...
# 3995           0.448
# 3996           0.448
# 3997           0.448
# 3998           0.448
# 3999           0.448
#
# [4000 rows x 5 columns]

# %%
fig, ax = plt.subplots()

ax.plot(log.Step, log["Temperature (K)"]/max(log["Temperature (K)"]))
ax.plot(log.Step, log["Potential Energy (kJ/mole)"]/max(log["Potential Energy (kJ/mole)"]))

# %%
fig, ax = plt.subplots(1, 2)

log.plot("Step", "RMSD", ax=ax[0])
log.plot("Step", "BCL RMSD", ax=ax[1])

fig.set_size_inches(24, 12)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RMSD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-1c3bfbd96c94> in <module>
#       1 fig, ax = plt.subplots(1, 2)
#       2
# ----> 3 log.plot("Step", "RMSD", ax=ax[0])
#       4 log.plot("Step", "BCL RMSD", ax=ax[1])
#       5
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     956
#     957                 # don't overwrite
# --> 958                 data = data[y].copy()
#     959
#     960                 if isinstance(data, ABCSeries):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'RMSD'
